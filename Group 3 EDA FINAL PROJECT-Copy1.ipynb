# %%
import pandas as pd #data preprocessing
import matplotlib.pyplot as plt #data visualization
import seaborn as sns #data visualization
import missingno as msno # missing data visualization
from collections import Counter #
import warnings
warnings.filterwarnings('ignore')

# %%
st = pd.read_csv(r"C:\Users\masha\Downloads\Sterling E-Commerce Data - Online Sales Data.csv")

# %%
st.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %%
st.tail(3)
# Out:
#                Category           City  County  Cust Id Customer Since  \
# 283080  Women's Fashion  Burkettsville  Mercer    81251     10/15/2013
# 283081  Women's Fashion  Burkettsville  Mercer    81251     10/15/2013
# 283082  Women's Fashion  Burkettsville  Mercer    81251     10/15/2013
#
#           Date of Order         Full Name Gender  Item Id     Order Id  \
# 283080  12/30/2021 0:00  Kester, Apolonia      F   700520  100428972.0
# 283081  12/30/2021 0:00  Kester, Apolonia      F   700517  100428972.0
# 283082  12/30/2021 0:00  Kester, Apolonia      F   700519  100428972.0
#
#        Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 283080            cod  Burkettsville   572291  Midwest    OH  azkester  45310
# 283081            cod  Burkettsville   572291  Midwest    OH  azkester  45310
# 283082            cod  Burkettsville   572291  Midwest    OH  azkester  45310
#
#         Qty Ordered  Total
# 283080            2   79.8
# ...

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283083 entries, 0 to 283082
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Category        283083 non-null  object
#  1   City            283083 non-null  object
#  2   County          283083 non-null  object
#  3   Cust Id         283083 non-null  int64
#  4   Customer Since  283083 non-null  object
#  5   Date of Order   283083 non-null  object
#  6   Full Name       283083 non-null  object
#  7   Gender          283083 non-null  object
#  8   Item Id         283083 non-null  int64
#  9   Order Id        283078 non-null  float64
#  10  Payment Method  283083 non-null  object
#  11  Place Name      283083 non-null  object
#  12  Ref Num         283083 non-null  int64
#  13  Region          283083 non-null  object
#  14  State           283083 non-null  object
#  15  User Name       283083 non-null  object
# ...

# %%
#Dimension of the data
st.shape
# Out:
# (283083, 19)

# %%
# checking for the features of the column in the dataset
st.columns
# Out:
# Index(['Category', 'City', 'County', 'Cust Id', 'Customer Since',
#        'Date of Order', 'Full Name', 'Gender', 'Item Id', 'Order Id',
#        'Payment Method', 'Place Name', 'Ref Num', 'Region', 'State',
#        'User Name', 'Zip', 'Qty Ordered', 'Total'],
#       dtype='object')

# %%
st.describe()
# Out:
#              Cust Id        Item Id      Order Id        Ref Num  \
# count  283083.000000  283083.000000  2.830780e+05  283083.000000
# mean    70106.816026  741747.110628  1.004570e+08  561107.885991
# std     30215.394879   95664.609013  6.090992e+04  256101.205409
# min         4.000000  574769.000000  1.003547e+08  111127.000000
# 25%     56640.000000  659898.500000  1.004047e+08  341071.000000
# 50%     74320.000000  742471.000000  1.004518e+08  565623.000000
# 75%     92371.000000  826078.500000  1.005134e+08  782211.000000
# max    115326.000000  905208.000000  1.005624e+08  999981.000000
#
#                  Zip    Qty Ordered          Total
# count  283083.000000  283083.000000  283083.000000
# mean    49147.171374       3.008224     816.230712
# std     27235.561738       4.565168    1986.164932
# min       210.000000       1.000000       0.000000
# 25%     26264.000000       2.000000      49.900000
# 50%     48808.000000       2.000000     149.800000
# ...

# %%
# Data cleaning (extract date and month) 
# order id 
# How frequently the customer order
# plot gender against revenue
# Highest order by city
# Gender count
# Payment method by gender
# Payment method by revenue
# product category 
# product category by quantity order

# %% [markdown]
# Data Cleaning

# %%
#In the dataset colunn 9 has some missing values 
miss_vals =st.isnull().sum()
miss_vals
# Out:
# Category          0
# City              0
# County            0
# Cust Id           0
# Customer Since    0
# Date of Order     0
# Full Name         0
# Gender            0
# Item Id           0
# Order Id          5
# Payment Method    0
# Place Name        0
# Ref Num           0
# Region            0
# State             0
# User Name         0
# Zip               0
# Qty Ordered       0
# Total             0
# dtype: int64

# %%
st.isnull()
# Out:
#         Category   City  County  Cust Id  Customer Since  Date of Order  \
# 0          False  False   False    False           False          False
# 1          False  False   False    False           False          False
# 2          False  False   False    False           False          False
# 3          False  False   False    False           False          False
# 4          False  False   False    False           False          False
# ...          ...    ...     ...      ...             ...            ...
# 283078     False  False   False    False           False          False
# 283079     False  False   False    False           False          False
# 283080     False  False   False    False           False          False
# 283081     False  False   False    False           False          False
# 283082     False  False   False    False           False          False
#
#         Full Name  Gender  Item Id  Order Id  Payment Method  Place Name  \
# ...

# %%
st[st.isnull().any(axis=1)]
# Out:
#                  Category          City    County  Cust Id Customer Since  \
# 38758             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 38759             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 133217  Mobiles & Tablets    Rock Point   Charles    92075       4/8/2014
# 145889  Mobiles & Tablets     Uniopolis  Auglaize   111166      2/23/2017
# 224999          Computing    Barrington    Camden    40853      8/24/2009
#
#          Date of Order            Full Name Gender  Item Id  Order Id  \
# 38758    8/4/2022 0:00          Wright, Man      M   879766       NaN
# 38759    8/4/2022 0:00          Wright, Man      M   879765       NaN
# 133217   4/1/2022 0:00  Torkelson, Berneice      F   767619       NaN
# 145889  7/21/2022 0:00      Cannon, Shamika      F   872703       NaN
# 224999  8/12/2022 0:00    Robichaux, Marion      M   883358       NaN
#
#        Payment Method    Place Name  Ref Num     Region State    User Name  \
# ...

# %%
st.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %%
st["Date of Order"] = pd.to_datetime(st["Date of Order"])
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283083 entries, 0 to 283082
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Category        283083 non-null  object
#  1   City            283083 non-null  object
#  2   County          283083 non-null  object
#  3   Cust Id         283083 non-null  int64
#  4   Customer Since  283083 non-null  object
#  5   Date of Order   283083 non-null  datetime64[ns]
#  6   Full Name       283083 non-null  object
#  7   Gender          283083 non-null  object
#  8   Item Id         283083 non-null  int64
#  9   Order Id        283078 non-null  float64
#  10  Payment Method  283083 non-null  object
#  11  Place Name      283083 non-null  object
#  12  Ref Num         283083 non-null  int64
#  13  Region          283083 non-null  object
#  14  State           283083 non-null  object
#  15  User Name       283083 non-null  object
# ...

# %%
#extarct month, month_name and quarter from date of order
# st['year'] = st["Date of Order"].dt.year
st['month'] = st["Date of Order"].dt.month
st['month_name'] = st["Date of Order"].dt.month_name()
st['quarter'] = st["Date of Order"].dt.quarter
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283083 entries, 0 to 283082
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Category        283083 non-null  object
#  1   City            283083 non-null  object
#  2   County          283083 non-null  object
#  3   Cust Id         283083 non-null  int64
#  4   Customer Since  283083 non-null  object
#  5   Date of Order   283083 non-null  datetime64[ns]
#  6   Full Name       283083 non-null  object
#  7   Gender          283083 non-null  object
#  8   Item Id         283083 non-null  int64
#  9   Order Id        283078 non-null  float64
#  10  Payment Method  283083 non-null  object
#  11  Place Name      283083 non-null  object
#  12  Ref Num         283083 non-null  int64
#  13  Region          283083 non-null  object
#  14  State           283083 non-null  object
#  15  User Name       283083 non-null  object
# ...

# %%
st.head(3)
# Out:
#           Category        City     County  Cust Id Customer Since  \
# 0  Health & Sports        Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion  Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion  Belleville  St. Clair   112386      6/23/2005
#
#   Date of Order       Full Name Gender  Item Id     Order Id  ... Ref Num  \
# 0    2022-08-07  Renaud, Maudie      F   880913  100547952.0  ...  352808
# 1    2022-08-08  Shimp, Mariela      F   881493  100548328.0  ...  310849
# 2    2022-08-08  Shimp, Mariela      F   881492  100548328.0  ...  310849
#
#     Region  State User Name    Zip Qty Ordered  Total  month  month_name  \
# 0  Midwest     IA  mcrenaud  50519           3   32.0      8      August
# 1  Midwest     IL   mgshimp  62223           2   74.8      8      August
# 2  Midwest     IL   mgshimp  62223           2   74.9      8      August
#
#    quarter
# 0        3
# 1        3
# 2        3
#
# [3 rows x 22 columns]

# %%
#gender count 
gender_counts = st['Gender'].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
#Percentage of order by gender
fig,ax = plt.subplots(figsize=(5,5))
count = Counter(st['Gender'])
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f' {p: .2f}%')
ax.set_title("Percentage of order by gender")
plt.show();

# %%
# # lets try pie chart 
# gender_counts = st['Gender'].value_counts()
# lables = gender_counts.index
# sizes = gender_counts.values
# plt.pie(sizes, labels=lables, )
# # plt.bar(gender_counts.index, gender_counts.values)
# # plt.xlabel('Gender')
# # plt.ylabel('Count')
# plt
# plt.title('Gender Distribution')
# plt.show()

# %%
st.describe()
# Out:
#              Cust Id        Item Id      Order Id        Ref Num  \
# count  283083.000000  283083.000000  2.830780e+05  283083.000000
# mean    70106.816026  741747.110628  1.004570e+08  561107.885991
# std     30215.394879   95664.609013  6.090992e+04  256101.205409
# min         4.000000  574769.000000  1.003547e+08  111127.000000
# 25%     56640.000000  659898.500000  1.004047e+08  341071.000000
# 50%     74320.000000  742471.000000  1.004518e+08  565623.000000
# 75%     92371.000000  826078.500000  1.005134e+08  782211.000000
# max    115326.000000  905208.000000  1.005624e+08  999981.000000
#
#                  Zip    Qty Ordered          Total          month  \
# count  283083.000000  283083.000000  283083.000000  283083.000000
# mean    49147.171374       3.008224     816.230712       7.353179
# std     27235.561738       4.565168    1986.164932       3.838077
# min       210.000000       1.000000       0.000000       1.000000
# ...

# %%
st.describe(include=['object','bool'])
# Out:
#                  Category    City     County       Full Name  Gender  \
# count              283083  283083     283083          283083  283083
# unique                 15   15668       2518           63610       2
# top     Mobiles & Tablets  Dekalb  Jefferson  Gonzalez, Joel       M
# freq                60954    2525       3510            2524  144295
#
#        Payment Method Place Name  Region   State   User Name month_name  \
# count          283083     283083  283083  283083      283083     283083
# unique             13      15668       4      49       63407         12
# top               cod     Dekalb   South      TX  jugonzalez   December
# freq           101750       2525  103482   17510        2524      81607
#
#                            cus_group
# count                         283083
# unique                             2
# top     New Customer(From 2006-2016)
# freq                          174666

# %%
max_value = st['Customer Since'].max()
max_value
# Out:
# Timestamp('2017-07-28 00:00:00')

# %%
min_value = st['Customer Since'].min()
min_value
# Out:
# Timestamp('1978-11-04 00:00:00')

# %%
#create a function for customer group from customer since to determine old and new customers
def cus_group(x):
    if x <= 2006:
        return "Old Customer(From 1986-2006)"
    else:
        return "New Customer(From 2006-2016)"

# %%
cus_group(2006)
# Out:
# 'Old Customer(From 1986-2006)'

# %%
st.tail()
# Out:
#                Category           City  County  Cust Id Customer Since  \
# 283078  Women's Fashion  Burkettsville  Mercer    81251     2013-10-15
# 283079  Women's Fashion  Burkettsville  Mercer    81251     2013-10-15
# 283080  Women's Fashion  Burkettsville  Mercer    81251     2013-10-15
# 283081  Women's Fashion  Burkettsville  Mercer    81251     2013-10-15
# 283082  Women's Fashion  Burkettsville  Mercer    81251     2013-10-15
#
#        Date of Order         Full Name Gender  Item Id     Order Id  ...  \
# 283078    2021-12-30  Kester, Apolonia      F   700522  100428972.0  ...
# 283079    2021-12-30  Kester, Apolonia      F   700518  100428972.0  ...
# 283080    2021-12-30  Kester, Apolonia      F   700520  100428972.0  ...
# 283081    2021-12-30  Kester, Apolonia      F   700517  100428972.0  ...
# 283082    2021-12-30  Kester, Apolonia      F   700519  100428972.0  ...
#
#        State User Name    Zip Qty Ordered Total month  month_name  quarter  \
# ...

# %%
st.head(10)
# Out:
#             Category           City     County  Cust Id Customer Since  \
# 0    Health & Sports           Bode   Humboldt   112285     2008-02-11
# 1      Men's Fashion     Belleville  St. Clair   112386     2005-06-23
# 2      Men's Fashion     Belleville  St. Clair   112386     2005-06-23
# 3          Computing  Young America     Carver   112501     2013-09-15
# 4      Entertainment  Young America     Carver   112501     2013-09-15
# 5      Men's Fashion   Francesville    Pulaski   112235     2013-01-03
# 6  Mobiles & Tablets   Francesville    Pulaski   112235     2013-01-03
# 7  Mobiles & Tablets   Francesville    Pulaski   112235     2013-01-03
# 8  Mobiles & Tablets   Francesville    Pulaski   112235     2013-01-03
# 9  Mobiles & Tablets   Francesville    Pulaski   112235     2013-01-03
#
#   Date of Order         Full Name Gender  Item Id     Order Id  ... State  \
# 0    2022-08-07    Renaud, Maudie      F   880913  100547952.0  ...    IA
# ...

# %%
st["Customer Since"] = pd.to_datetime(st["Customer Since"])

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283083 entries, 0 to 283082
# Data columns (total 24 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Category        283083 non-null  object
#  1   City            283083 non-null  object
#  2   County          283083 non-null  object
#  3   Cust Id         283083 non-null  int64
#  4   Customer Since  283083 non-null  datetime64[ns]
#  5   Date of Order   283083 non-null  datetime64[ns]
#  6   Full Name       283083 non-null  object
#  7   Gender          283083 non-null  object
#  8   Item Id         283083 non-null  int64
#  9   Order Id        283078 non-null  float64
#  10  Payment Method  283083 non-null  object
#  11  Place Name      283083 non-null  object
#  12  Ref Num         283083 non-null  int64
#  13  Region          283083 non-null  object
#  14  State           283083 non-null  object
#  15  User Name       283083 non-null  object
# ...

# %%
st['year'] = st["Customer Since"].dt.year
# st['year'] = st["Date of Order"].dt.year

#extract year from customer Sinceabs
st['cus_group'] = st['year'].apply(cus_group)

# %%
st.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285     2008-02-11
# 1    Men's Fashion     Belleville  St. Clair   112386     2005-06-23
# 2    Men's Fashion     Belleville  St. Clair   112386     2005-06-23
# 3        Computing  Young America     Carver   112501     2013-09-15
# 4    Entertainment  Young America     Carver   112501     2013-09-15
#
#   Date of Order        Full Name Gender  Item Id     Order Id  ... State  \
# 0    2022-08-07   Renaud, Maudie      F   880913  100547952.0  ...    IA
# 1    2022-08-08   Shimp, Mariela      F   881493  100548328.0  ...    IL
# 2    2022-08-08   Shimp, Mariela      F   881492  100548328.0  ...    IL
# 3    2022-08-18  Doiron, Latrina      F   886067  100551079.0  ...    MN
# 4    2022-08-20  Doiron, Latrina      F   886878  100551618.0  ...    MN
#
#   User Name    Zip Qty Ordered   Total month  month_name  quarter  year  \
# ...

# %%
#Count of Customer group
sns.countplot(x="cus_group", data=st);
plt.title('Count of Customer group');

# %%
# Distriution of customers from 1986 to 2016
plt.title('Distriution of customers from 1986 to 2016')
sns.distplot(st['year'])
# Out:
# <Axes: title={'center': 'Distriution of customers from 1986 to 2016'}, xlabel='year', ylabel='Density'>

# %%
# plt.title('Count of Order by Quarter');
plt.figure(figsize=(15,10))
sns.countplot(x="quarter",data=st);
plt.title('Count of Order by Quarter');

# %%
#plt.title('Count of Order by State');
plt.figure(figsize=(15,10))
sns.countplot(x="State",data=st);
plt.title('Count of Order by State')
plt.xticks(rotation=90)
plt.show();

# %%
#st.sort_values["State", inplace==True, ascending= True]

# %%
sns.countplot(x="Region", data=st)
st.sort_values("Region", inplace=True, ascending=False)
plt.title('Count of Order by Region');

# %%
# count = Counter(st['Gender'])
# ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f' {p: .2f}%', ax=axs[1,1])
# axs=[1,1].set_title("percentage of transactions by gender")
# # plt.show();


fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20,20))
qty_ord = st.groupby('cus_group')['Qty Ordered'].sum().reset_index()
sns.barplot(x='cus_group', data=qty_ord, y='Qty Ordered', ax=axs[0,0])
axs[0,0].set_title('Customer Group by Quantity Ordered')

sales= st.groupby('cus_group')['Total'].sum().reset_index()
sns.barplot(x='cus_group', data=st, y='Total', ax=axs[0,1])
axs[0,1].set_title('Customer Group by Total')

category = st.groupby('Category')['Qty Ordered'].sum().reset_index()
sns.barplot(y='Category', data=st, x='Qty Ordered', ax=axs[1,0])
axs[1,0].set_title('Quantity Ordered by Category');

total = st.groupby('Category')['Total'].sum().reset_index()
sns.barplot(y='Category', data=st, x='Total', ax=axs[1,1])
axs[1,1].set_title('Sales by Category')
# Out:
# Text(0.5, 1.0, 'Sales by Category')

# %%
# Count of Payment method
fig, ax = plt.subplots(figsize=(5, 5))
sns.countplot(x="Payment Method", data=st, ax=ax)
plt.title('Count of Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Revenue by Payment method
fig, ax = plt.subplots(figsize=(5, 5))
payment_method_revenue = st.groupby('Payment Method')['Total'].sum().reset_index()
sns.barplot(x='Payment Method', y='Total', data=payment_method_revenue, ax=ax)
ax.set_title('Revenue by Payment method')
ax.set_xlabel('Payment Method')
ax.set_ylabel('Total Revenue')
plt.xticks(rotation=90)
plt.show()

# %%
# Count of Payment method by Region
fig, ax = plt.subplots(figsize=(5, 5))
payment_method_region = st.groupby('Region')['Payment Method'].count().reset_index()
sns.scatterplot(x='Region', y='Payment Method', data=payment_method_region, ax=ax)
ax.set_title('Payment method by Region')
ax.set_xlabel('Region')
ax.set_ylabel('Count of Payment Method')
plt.xticks(rotation=90)
plt.show()

# %%
# Count of Payment method by cus_group
fig, ax = plt.subplots(figsize=(10, 10))
payment_method_region = st.groupby('cus_group')['Payment Method'].count().reset_index()
sns.barplot(x='cus_group', y='Payment Method', data=payment_method_region, ax=ax)
ax.set_title('Count of Payment method by cus_group')
ax.set_xlabel('cus_group')
ax.set_ylabel('Count of Payment Method')
plt.show()

# %% [raw]
# EDA ANALYSIS
# 1.	Gender count & Percentage of order by gender
# The distribution of orders between male and female customers is almost balanced, with a slightly higher proportion of male customers. This suggests that both genders are actively engaging in online shopping on Sterling E-commerce platform, which is a positive aspect of thier business.
# Recommendation
# Gender Preferences: Analyze the purchasing patterns and preferences of male and female customers to identify any significant differences. This analysis can help the company to understand which product categories or specific items are more popular among each gender.
#
# 2.	(a) Count of Customer group
# New Customer Acquisition: The higher count of new customers ordering products compared to old customers indicates that Sterling E-commerce is successful in attracting new users to the platform. This is a positive sign as it shows a growing customer base.
# However,
# 2b.	Distributions of customers from 1986 to 2016
# Retention and Loyalty: The right-skewed distribution suggests that there are fewer old customers ordering products compared to new customers.
# Recommendations for 2a and 2b
# i.	Customer Retention Strategies: Implement strategies to retain existing customers and encourage repeat purchases. This can include loyalty programs, personalized offers, exclusive discounts, and excellent customer service. Building strong relationships with existing customers can lead to long-term loyalty and higher customer satisfaction.
# ii.	New Customer Onboarding: Enhance the onboarding process for new customers to ensure a smooth and positive experience. Provide clear instructions, user-friendly interfaces, and proactive support to help new customers navigate the platform and make their first purchases.
# 3.	Count of Order by Quarter
# Count of Order by Quarter showed significant increase at 4th quarter followed by 2nd quarter, followed by 1st quarter, with the 3rd quarter having the least count of order.
# Insight
# Seasonal Variation: The significant increase in orders during the 4th quarter suggests a seasonal trend, likely influenced by holiday shopping, such as Christmas and end-of-year sales. This indicates that customers are more active and make more purchases during the holiday season. The 2nd quarter also shows a notable increase, which could be influenced by factors such as seasonal promotions or events such as summer vacations.
# Recommendations
# i.	Seasonal Promotions: Capitalize on the increased demand during the 4th quarter and 2nd quarter by offering targeted seasonal promotions, discounts, and special deals. Create marketing campaigns that align with holidays, events, and customer preferences during these periods to maximize sales and customer engagement.
# ii.	Off-Season Strategies: Develop strategies to boost sales and customer engagement during the 3rd quarter when order counts are relatively lower. This could involve implementing targeted marketing campaigns, introducing exclusive offers, or collaborating with partners to create special promotions to stimulate demand during this period.
#
# 4.	Count of order by State & Count of order by region
# Count of order by state showed that; Texas is the highest selling state followed by, California, New York, and Pennsylvania respectively. This indicates that these states have a significant customer base and demand for products offered by Sterling E-commerce. And according to our research on google, these states are all populous states with large markets.
# Furthermore, the Count of order by region; indicates “regional sales distribution” because Texas is in the southern region of the USA, which is why the southern region has the highest order as seen in the chart followed by the Midwest region where California; the second highest selling state is located.
# Recommendations
# Sterling E-Commerce should Build upon the success in Texas, California, New York, and Pennsylvania by implementing targeted marketing campaigns specific to these states while also consider expanding the customer base by targeting regions with untapped potential.
#
#
# 5.	Subplots
# [0,0] Customer Group by Quantity Ordered: The analysis reveals that the new customer group shows a significantly higher trend in terms of quantity ordered. This indicates that new customers are placing larger orders or purchasing higher quantities of products compared to the old customer group. This could be an encouraging sign for the business as it indicates that the acquisition of new customers is resulting in increased sales volume.
# [0,1] Customer group by Total Revenue: On the other hand, the analysis of total revenue suggests that the old customer group shows a significantly higher trend. This implies that although the new customers are ordering larger quantities, the revenue generated by the old customer group is higher. It could be due to the fact that old customers make higher-value purchases or have a higher average order value.
#
#
# Recommendations [0,0] [0,1]
# Focus on customer retention: Given the higher total revenue generated by the old customer group, it is important to maximize customer lifetime value (CLV) and prioritize customer retention strategies. This can be done by Implementing loyalty programs, personalized offers, and excellent customer service to keep the old customers engaged and encourage repeat purchases. For new customers, focus on showcasing the value and benefits of their products to encourage them to make higher-value purchases.
#
# [1,0]	Quantity Ordered by Category: The analysis reveals that the "Superstore" category has the highest quantity ordered, indicating that it is the most popular category in terms of the number of products purchased. The "Others" category comes next, followed by the "School & Education" category. This suggests that customers are more inclined to purchase products from the Superstore category.
# [1,1]	Sales by Category: On the other hand, when examining sales by category, the "Mobile & Tablets" category stands out as the highest revenue-generating category. This indicates that although the Superstore category has the highest quantity ordered, the Mobile & Tablets category generates higher revenue, implying that the products in this category have a higher price point; that is they are more expensive and more profitable compared to other categories.
# Recommendations [1,0] [1,1]
# Focus on promoting high-revenue categories: Given that mobiles & tablets generate the highest revenue, allocate marketing and promotional efforts to highlight these products. Implement targeted advertising campaigns, bundle offers, or exclusive discounts to attract more customers to this category.
# Optimize the superstore category: As the category with the highest quantity ordered, explore ways to increase the average order value within the superstore category. Consider upselling or cross-selling strategies by recommending complementary products or offering bundle deals to encourage customers to purchase more items from this category.
# Explore opportunities in the "Others" category: Promote these products separately or consider creating sub-categories within the "Others" category to improve visibility and drive more sales.
# Enhance the school & education category: collaborate with educational institutions or professionals, and implement targeted marketing strategies to attract more customers to this category
#
# 6.	Count of Payment Method & Revenue by Payment method
# The most preferred payment method among customers is COD (Cash on Delivery), indicating that a significant portion of customers prefers the convenience of paying in cash upon delivery. Following COD, the second most preferred payment method is Easypay.
# Although COD is the most preferred payment method, the highest revenue is generated from Easypay. This suggests that even though customers may choose COD for payment, transactions made through Easypay tend to have higher order values on average. Additionally, Bank Alfalah and Easypay Voucher are also generating significant revenue.
# Recommendations
# Promote Easypay: Since Easypay generates higher revenue despite being the second most preferred payment method, it would be beneficial for Sterling E-commerce to promote and incentivize customers to choose Easypay. This can be done by offering discounts, exclusive deals, or additional benefits for customers using Easypay.
# Analyze Bank Alfalah and Easypay Voucher Usage Pattern to Identify the customer segments or marketing channels that drive transactions through these payment methods and strategize marketing efforts accordingly to further increase revenue from them.
# 7.	Count of Payment method by region
# The south and the Midwest has the highest “count of payment method by region” which is the same trend as the “count of order by region”. Indicating that customers in the South and Midwest regions of the USA have a similar preference for payment methods as they do for placing orders. This alignment between the count of payment methods and the count of orders by region suggests a correlation between regional shopping behaviour and payment preferences.
# The fact that the South and Midwest regions have the highest count of both “payment methods” and “orders” indicates that customers in these regions are actively engaged in online shopping.
# Recommendations
# Therefore, it is essential for Sterling E-commerce to optimize the availability and usability of the preferred payment methods in these regions. Ensure that the payment infrastructure is robust, reliable, and convenient for customers using their preferred payment methods.
# 8.	Count of Payment method by cus_group
# The analysis of the count of payment methods by customer group indicates that there is a higher trend in the "New Customer (From 2006-2016)" category compared to the "Old Customer (From 1986-2006)" category. This suggests that new customers, who have joined Sterling E-commerce more recently, are utilizing a wider variety of payment methods compared to the older customers. Indicating the willingness of new customers to explore and adopt different payment options.
# Recommendations
# Education and Communication: Provide clear and comprehensive information about the available payment methods to both new and old customers. Highlight the advantages, security features, and ease of use for each payment option. This can help bridge the knowledge gap and encourage older customers to explore and utilize a wider range of payment methods.
# Personalization and Customization: Leverage customer data and insights to personalize the payment experience.
# Seamless Integration: Ensure a seamless and user-friendly payment experience across all platforms and devices. Optimize the checkout process, streamline payment flows, and minimize friction points to make it convenient for customers to complete their transactions using their preferred payment methods.
#
# CONCLUSION
# In conclusion, Sterling E-Commerce should Continuously improve user experience on their e-commerce platform by ensuring a seamless and user-friendly interface, fast and secure payment options, and efficient customer support. This will contribute to higher customer satisfaction and encourage positive word-of-mouth recommendations. Thank you!
